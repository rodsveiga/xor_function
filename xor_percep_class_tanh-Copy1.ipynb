# %% [markdown]
# # Code Example of a Neural Network for The Function XOR
#
# Based on the implementation by [Chih-Ling Hsu](https://chih-ling-hsu.github.io/2017/08/30/NN-XOR).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import time

from net import NeuralNetwork
from net import Plots
from perceptron import Perceptron

# %% [markdown]
# ## Neural Network Training

# %% [markdown]
# First we define network architecture, activation function, input data with labels. The training is called by the method `fit()`.

# %%
net_arch = [2, 2, 2, 2, 2, 2, 2, 2, 1]

# Initialize the NeuralNetwork
net = NeuralNetwork(net_arch,
                    act= 'tanh')

# Set the input data
X = np.array([[-1, -1], [-1, 1],
               [1, -1], [1, 1]])


# Set the labels, the correct results for the xor operation
y = np.array([-1, 1, 
              1, -1])

# Call the fit function and train the network for a chosen number of epochs
net.fit(X, 
        y,
        epochs= 10000,
        int_rep= True,
        int_rep_index= -2,
        save_weights= True,
        learning_rate= 0.01)

# Show the prediction results
print("Final prediction")
for s in X:
    print(s, net.predict_single_data(s))
# Out:
# epochs: 10000
# Final prediction
# [-1 -1] -0.9621407451087527
# [-1  1] 0.9610146824647805
# [ 1 -1] 0.9583510359953559
# [1 1] -0.959281255300966

# %% [markdown]
# Decision boundaries:

# %%
plots = Plots(X, y, net)
plots.decision_regions()

# %% [markdown]
# The internal representations and weights during training can be extract to further analysis.

# %%
int_rep = net.int_rep_dyn()
weights = net.weights_dyn()

# %%
name = 'output/int_rep_tanh_ep10000'

with open(name, 'wb') as f:
    pickle.dump(int_rep, f)

# %%
name = 'output/int_rep_tanh_ep10000'

with open(name, 'rb') as f:
    int_rep = pickle.load(f)

# %%
name = 'output/weights_tanh_ep10000'

with open(name, 'wb') as f:
    pickle.dump(weights, f)

# %%
name = 'output/weights_tanh'

with open(name, 'rb') as f:
    weights = pickle.load(f)

# %% [markdown]
# ### Linear separability over layers: perceptron
#
# Note that the perceptron works with $\{ 0, 1\}$ inputs instead of $\{ -1, + 1 \}$.

# %%
layer = []
epoch = []
linear_sep_ = []

y = np.array([-1, 1, 
              1, -1])

y_p = ((y + 1)/2).astype(int)

for j in range(1, len(int_rep), 10):
       
    t0 = time.time()
    
    print('Epoch %d' % j)

    for k in range(len(int_rep[1]) - 1 ):
        
        #t0_l = time.time()
        
        int_p = (int_rep[j][k] + 1.)/2.
        
        linear_sep = Perceptron(int_p, y_p).train()
        
        linear_sep_.append(linear_sep)
        
        layer.append(k)
        epoch.append(j)
        
        #t1_l = time.time()
        #deltaT = t1_l - t0_l
        #print('layer %d time %.2f s' % (k, deltaT ) )
        
    t1 = time.time()
    deltaT = t1 - t0
    
    print('time elapsed epoch %.2f s' % deltaT)
    
    #if (j % 100000 == 0):
    #    name = '../../../output/linear_sep_ep%d' % j
    #    with open(name, 'wb') as f:
    #        pickle.dump(linear_sep_, f)
# Out:
# Epoch 1
# time elapsed epoch 2.89 s
# Epoch 11
# time elapsed epoch 2.89 s
# Epoch 21
# time elapsed epoch 3.07 s
# Epoch 31
# time elapsed epoch 3.07 s
# Epoch 41
# time elapsed epoch 2.87 s
# Epoch 51
# time elapsed epoch 2.77 s
# Epoch 61
# time elapsed epoch 2.73 s
# Epoch 71
# time elapsed epoch 2.83 s
# Epoch 81
# time elapsed epoch 3.07 s
# Epoch 91
# time elapsed epoch 3.04 s
# Epoch 101
# time elapsed epoch 2.92 s
# Epoch 111
# time elapsed epoch 3.02 s
# Epoch 121
# time elapsed epoch 3.06 s
# Epoch 131
# time elapsed epoch 3.10 s
# Epoch 141
# time elapsed epoch 2.93 s
# Epoch 151
# time elapsed epoch 2.86 s
# Epoch 161
# time elapsed epoch 2.75 s
# Epoch 171
# time elapsed epoch 2.96 s
# Epoch 181
# time elapsed epoch 3.12 s
# Epoch 191
# time elapsed epoch 3.00 s
# Epoch 201
# time elapsed epoch 3.04 s
# Epoch 211
# time elapsed epoch 3.08 s
# Epoch 221
# time elapsed epoch 3.11 s
# Epoch 231
# time elapsed epoch 3.05 s
# Epoch 241
# time elapsed epoch 3.08 s
# Epoch 251
# time elapsed epoch 3.11 s
# Epoch 261
# time elapsed epoch 3.06 s
# Epoch 271
# time elapsed epoch 3.00 s
# Epoch 281
# time elapsed epoch 3.25 s
# Epoch 291
# time elapsed epoch 3.11 s
# Epoch 301
# time elapsed epoch 3.02 s
# Epoch 311
# time elapsed epoch 3.04 s
# Epoch 321
# time elapsed epoch 3.05 s
# Epoch 331
# time elapsed epoch 3.06 s
# Epoch 341
# time elapsed epoch 3.00 s
# Epoch 351
# time elapsed epoch 3.07 s
# Epoch 361
# time elapsed epoch 2.95 s
# Epoch 371
# time elapsed epoch 2.99 s
# Epoch 381
# time elapsed epoch 3.06 s
# Epoch 391
# time elapsed epoch 3.00 s
# Epoch 401
# time elapsed epoch 3.02 s
# Epoch 411
# time elapsed epoch 3.06 s
# Epoch 421
# time elapsed epoch 2.88 s
# Epoch 431
# time elapsed epoch 2.92 s
# Epoch 441
# time elapsed epoch 3.04 s
# Epoch 451
# time elapsed epoch 2.88 s
# Epoch 461
# time elapsed epoch 2.93 s
# Epoch 471
# time elapsed epoch 3.16 s
# Epoch 481
# time elapsed epoch 3.05 s
# Epoch 491
# time elapsed epoch 3.02 s
# Epoch 501
# time elapsed epoch 3.08 s
# Epoch 511
# time elapsed epoch 3.04 s
# Epoch 521
# time elapsed epoch 3.16 s
# Epoch 531
# time elapsed epoch 2.94 s
# Epoch 541
# time elapsed epoch 3.05 s
# Epoch 551
# time elapsed epoch 3.02 s
# Epoch 561
# time elapsed epoch 3.09 s
# Epoch 571
# time elapsed epoch 3.00 s
# Epoch 581
# time elapsed epoch 3.02 s
# Epoch 591
# time elapsed epoch 3.17 s
# Epoch 601
# time elapsed epoch 3.11 s
# Epoch 611
# time elapsed epoch 3.09 s
# Epoch 621
# time elapsed epoch 3.06 s
# Epoch 631
# time elapsed epoch 3.12 s
# Epoch 641
# time elapsed epoch 2.99 s
# Epoch 651
# time elapsed epoch 3.03 s
# Epoch 661
# time elapsed epoch 3.06 s
# Epoch 671
# time elapsed epoch 3.03 s
# Epoch 681
# time elapsed epoch 3.14 s
# Epoch 691
# time elapsed epoch 3.09 s
# Epoch 3171
# time elapsed epoch 0.92 s
# Epoch 3181
# time elapsed epoch 0.91 s
# Epoch 3191
# time elapsed epoch 0.81 s
# Epoch 3201
# time elapsed epoch 0.93 s
# Epoch 3211
# time elapsed epoch 0.77 s
# Epoch 3221
# time elapsed epoch 0.85 s
# Epoch 3231
# time elapsed epoch 0.87 s
# Epoch 3241
# time elapsed epoch 0.87 s
# Epoch 3251
# time elapsed epoch 0.88 s
# Epoch 3261
# time elapsed epoch 0.94 s
# Epoch 3271
# time elapsed epoch 0.90 s
# Epoch 3281
# time elapsed epoch 0.91 s
# Epoch 3291
# time elapsed epoch 0.96 s
# Epoch 3301
# time elapsed epoch 0.89 s
# Epoch 3311
# time elapsed epoch 0.88 s
# Epoch 3321
# time elapsed epoch 1.03 s
# Epoch 3331
# time elapsed epoch 0.97 s
# Epoch 3341
# time elapsed epoch 0.94 s
# Epoch 3351
# time elapsed epoch 0.98 s
# Epoch 3361
# time elapsed epoch 1.03 s
# Epoch 3371
# time elapsed epoch 1.05 s
# Epoch 3381
# time elapsed epoch 0.96 s
# Epoch 3391
# time elapsed epoch 0.95 s
# Epoch 3401
# time elapsed epoch 0.99 s
# Epoch 3411
# time elapsed epoch 0.87 s
# Epoch 3421
# time elapsed epoch 0.99 s
# Epoch 3431
# time elapsed epoch 0.97 s
# Epoch 3441
# time elapsed epoch 1.01 s
# Epoch 3451
# time elapsed epoch 0.91 s
# Epoch 3461
# time elapsed epoch 1.01 s
# Epoch 3471
# time elapsed epoch 0.97 s
# Epoch 3481
# time elapsed epoch 0.98 s
# Epoch 3491
# time elapsed epoch 0.99 s
# Epoch 3501
# time elapsed epoch 1.01 s
# Epoch 3511
# time elapsed epoch 0.94 s
# Epoch 3521
# time elapsed epoch 0.99 s
# Epoch 3531
# time elapsed epoch 1.04 s
# Epoch 3541
# time elapsed epoch 0.98 s
# Epoch 3551
# time elapsed epoch 0.94 s
# Epoch 3561
# time elapsed epoch 0.84 s
# Epoch 3571
# time elapsed epoch 0.91 s
# Epoch 3581
# time elapsed epoch 0.90 s
# Epoch 3591
# time elapsed epoch 0.92 s
# Epoch 3601
# time elapsed epoch 0.84 s
# Epoch 3611
# time elapsed epoch 0.99 s
# Epoch 3621
# time elapsed epoch 0.96 s
# Epoch 3631
# time elapsed epoch 1.05 s
# Epoch 3641
# time elapsed epoch 0.91 s
# Epoch 3651
# time elapsed epoch 0.94 s
# Epoch 3661
# time elapsed epoch 0.94 s
# Epoch 3671
# time elapsed epoch 0.93 s
# Epoch 3681
# time elapsed epoch 0.95 s
# Epoch 3691
# time elapsed epoch 0.98 s
# Epoch 3701
# time elapsed epoch 0.89 s
# Epoch 3711
# time elapsed epoch 0.90 s
# Epoch 3721
# time elapsed epoch 0.95 s
# Epoch 3731
# time elapsed epoch 0.93 s
# Epoch 3741
# time elapsed epoch 0.97 s
# Epoch 3751
# time elapsed epoch 0.89 s
# Epoch 3761
# time elapsed epoch 0.90 s
# Epoch 3771
# time elapsed epoch 0.96 s
# Epoch 3781
# Epoch 6851
# time elapsed epoch 0.91 s
# Epoch 6861
# time elapsed epoch 1.00 s
# Epoch 6871
# time elapsed epoch 1.01 s
# Epoch 6881
# time elapsed epoch 0.99 s
# Epoch 6891
# time elapsed epoch 0.98 s
# Epoch 6901
# time elapsed epoch 0.92 s
# Epoch 6911
# time elapsed epoch 1.00 s
# Epoch 6921
# time elapsed epoch 0.92 s
# Epoch 6931
# time elapsed epoch 0.97 s
# Epoch 6941
# time elapsed epoch 0.98 s
# Epoch 6951
# time elapsed epoch 0.88 s
# Epoch 6961
# time elapsed epoch 0.95 s
# Epoch 6971
# time elapsed epoch 1.00 s
# Epoch 6981
# time elapsed epoch 0.92 s
# Epoch 6991
# time elapsed epoch 0.95 s
# Epoch 7001
# time elapsed epoch 0.94 s
# Epoch 7011
# time elapsed epoch 0.91 s
# Epoch 7021
# time elapsed epoch 0.92 s
# Epoch 7031
# time elapsed epoch 0.92 s
# Epoch 7041
# time elapsed epoch 0.96 s
# Epoch 7051
# time elapsed epoch 1.02 s
# Epoch 7061
# time elapsed epoch 1.02 s
# Epoch 7071
# time elapsed epoch 0.95 s
# Epoch 7081
# time elapsed epoch 0.93 s
# Epoch 7091
# time elapsed epoch 0.96 s
# Epoch 7101
# time elapsed epoch 0.96 s
# Epoch 7111
# time elapsed epoch 0.96 s
# Epoch 7121
# time elapsed epoch 0.95 s
# Epoch 7131
# time elapsed epoch 0.94 s
# Epoch 7141
# time elapsed epoch 0.80 s
# Epoch 7151
# time elapsed epoch 1.06 s
# Epoch 7161
# time elapsed epoch 0.95 s
# Epoch 7171
# time elapsed epoch 0.80 s
# Epoch 7181
# time elapsed epoch 0.93 s
# Epoch 7191
# time elapsed epoch 0.99 s
# Epoch 7201
# time elapsed epoch 0.95 s
# Epoch 7211
# time elapsed epoch 0.99 s
# Epoch 7221
# time elapsed epoch 0.98 s
# Epoch 7231
# time elapsed epoch 1.00 s
# Epoch 7241
# time elapsed epoch 1.00 s
# Epoch 7251
# time elapsed epoch 0.94 s
# Epoch 7261
# time elapsed epoch 0.92 s
# Epoch 7271
# time elapsed epoch 0.97 s
# Epoch 7281
# time elapsed epoch 0.99 s
# Epoch 7291
# time elapsed epoch 0.96 s
# Epoch 7301
# time elapsed epoch 0.98 s
# Epoch 7311
# time elapsed epoch 0.98 s
# Epoch 7321
# time elapsed epoch 1.01 s
# Epoch 7331
# time elapsed epoch 0.96 s
# Epoch 7341
# time elapsed epoch 1.00 s
# Epoch 7351
# time elapsed epoch 1.02 s
# Epoch 7361
# time elapsed epoch 0.94 s
# Epoch 7371
# time elapsed epoch 1.02 s
# Epoch 7381
# time elapsed epoch 0.99 s
# Epoch 7391
# time elapsed epoch 0.96 s
# Epoch 7401
# time elapsed epoch 0.94 s
# Epoch 7411
# time elapsed epoch 0.95 s
# Epoch 7421
# time elapsed epoch 1.00 s
# Epoch 7431
# time elapsed epoch 0.96 s
# Epoch 7441
# time elapsed epoch 0.96 s
# Epoch 7451
# time elapsed epoch 0.96 s
# Epoch 7461
# Epoch 9921
# time elapsed epoch 0.90 s
# Epoch 9931
# time elapsed epoch 0.87 s
# Epoch 9941
# time elapsed epoch 0.89 s
# Epoch 9951
# time elapsed epoch 0.98 s
# Epoch 9961
# time elapsed epoch 1.02 s
# Epoch 9971
# time elapsed epoch 0.89 s
# Epoch 9981
# time elapsed epoch 0.95 s
# Epoch 9991
# time elapsed epoch 0.91 s

# %%
name = 'output/lin_sep_tanh_ep_10000_step10'

with open(name, 'wb') as f:
    pickle.dump(linear_sep_, f)

# %%
len(linear_sep_)
# Out:
# 8000

# %%
len(epoch)
# Out:
# 8000

# %%
linear_sep_

# %%
slicing = len(linear_sep_)

f = plt.figure(figsize=(15,4))

scatters = plt.scatter(epoch[0:slicing], layer[0:slicing], c= linear_sep_[0:slicing])
cbar = plt.colorbar(scatters)
cbar.ax.set_yticklabels(['0', '', '', '', '', '1'])
cbar.set_label('Linear Sep', fontsize= 15, rotation= 90)
plt.ylabel('Layer', fontsize= 15)
plt.xlabel('Epoch', fontsize= 15)
plt.xscale('log')
plt.show()

# %%
slicing = len(linear_sep_)

f = plt.figure(figsize=(15,4))

scatters = plt.scatter(epoch[0:slicing], layer[0:slicing], c= linear_sep_[0:slicing])
cbar = plt.colorbar(scatters)
cbar.ax.set_yticklabels(['0', '', '', '', '', '1'])
cbar.set_label('Linear Sep', fontsize= 15, rotation= 90)
plt.ylabel('Layer', fontsize= 15)
plt.xlabel('Epoch', fontsize= 15)
#plt.xscale('log')
plt.xlim([1900, 2600])
plt.show()

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, 
                                       sharex=True,
                                       sharey=True,
                                       figsize=(10,15))
ax1.plot(l_minus_minus_x, marker='.', label= '$x_0$ = %d' % l_minus_minus_x[0])
ax1.plot(l_minus_minus_y, marker='.', label= '$y_0$ = %d' % l_minus_minus_y[0])
ax1.legend(fontsize= 12)
ax2.plot(l_minus_plus_x, marker='.', label= '$x_0$ = %d' % l_minus_plus_x[0])
ax2.plot(l_minus_plus_y, marker='.', label= '$y_0$ = %d' % l_minus_plus_y[0])
ax2.legend(fontsize= 12)
ax3.plot(l_plus_minus_x, marker='.', label= '$x_0$ = %d' % l_plus_minus_x[0])
ax3.plot(l_plus_minus_y, marker='.', label= '$y_0$ = %d' % l_plus_minus_y[0])
ax3.legend(fontsize= 12)
ax4.plot(l_plus_plus_x, marker='.', label= '$x_0$ = %d' % l_plus_plus_x[0])
ax4.plot(l_plus_plus_y, marker='.', label= '$y_0$ = %d' % l_plus_plus_y[0])
ax4.legend(fontsize= 12)
ax4.set_xlabel('Epochs', fontsize= 15)

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
#plt.xlim(-10, 1000)
#plt.legend()
plt.show()

# %% [markdown]
# ## Information processing

# %%
nn_trained = NeuralNetwork(net_arch,
                           act= 'tanh',
                           W= weights[-1])

# %%
x_dynamics = nn_trained.forward(X)

# %%
x_dynamics[-1]

# %%
l_minus_minus_x = []
l_minus_minus_y = []
l_minus_plus_x = []
l_minus_plus_y = []
l_plus_minus_x = []
l_plus_minus_y = []
l_plus_plus_x = []
l_plus_plus_y = []


for j in range(len(x_dynamics) - 1):
    
    l_minus_minus_x.append(x_dynamics[j][0][0])
    l_minus_minus_y.append(x_dynamics[j][0][1])
    l_minus_plus_x.append(x_dynamics[j][1][0])
    l_minus_plus_y.append(x_dynamics[j][1][1])
    l_plus_minus_x.append(x_dynamics[j][2][0])
    l_plus_minus_y.append(x_dynamics[j][2][1])
    l_plus_plus_x.append(x_dynamics[j][3][0])
    l_plus_plus_y.append(x_dynamics[j][3][1])

# %%
plot_dynamics(l_minus_minus_x, l_minus_minus_y,
              l_minus_plus_x, l_minus_plus_y,
              l_plus_minus_x, l_plus_minus_y,
              l_plus_plus_x, l_plus_plus_y,
              training= False)

# %%
for j in range(len(l_minus_minus_x)):
    
    ints = closed_segment_intersect([l_minus_minus_x[j], l_minus_minus_y[j]], 
                                    [l_plus_plus_x[j], l_plus_plus_y[j]],
                                    [l_minus_plus_x[j], l_minus_plus_y[j]], 
                                    [l_plus_minus_x[j], l_plus_minus_y[j]])
    
    sep = bool(abs(int(ints) - 1 ))
    
    print('Layer = %d' %j, 'Sep = %s' %sep)

# %%
def plot_dynamics(l_minus_minus_x, l_minus_minus_y,
                  l_minus_plus_x, l_minus_plus_y,
                  l_plus_minus_x, l_plus_minus_y,
                  l_plus_plus_x, l_plus_plus_y, 
                  training= False):
    
    if training:
        title = 'Training dynamics'
    else:
        title = 'Layer dynamics'
    
    
    xq = np.array(l_minus_minus_x)
    yq = np.array(l_minus_minus_y)

    plt.quiver(xq[:-1], yq[:-1], xq[1:]-xq[:-1], yq[1:]-yq[:-1], 
               scale_units= 'xy', 
               angles= 'xy', 
               scale= 1,
               width= 0.005,
               color= 'b', 
               headwidth= 5)
    plt.plot(xq, yq, 'o', markersize= 0.5, color= 'b')

    ###############################

    xq = np.array(l_minus_plus_x)
    yq = np.array(l_minus_plus_y)

    plt.quiver(xq[:-1], yq[:-1], xq[1:]-xq[:-1], yq[1:]-yq[:-1], 
               scale_units= 'xy', 
               angles= 'xy', 
               scale= 1,
               width= 0.005,
               color= 'r',
               headwidth= 5)
    plt.plot(xq, yq, 'o', markersize= 0.5, color= 'r')

    ###############################

    xq = np.array(l_plus_minus_x)
    yq = np.array(l_plus_minus_y)

    plt.quiver(xq[:-1], yq[:-1], xq[1:]-xq[:-1], yq[1:]-yq[:-1], 
               scale_units= 'xy', 
               angles= 'xy', 
               scale= 1,
               width= 0.005,
               color= 'g',
               headwidth= 5)
    plt.plot(xq, yq, 'o', markersize= 0.5, color= 'g')

    ###############################

    xq = np.array(l_plus_plus_x)
    yq = np.array(l_plus_plus_y)
    
    plt.quiver(xq[:-1], yq[:-1], xq[1:]-xq[:-1], yq[1:]-yq[:-1], 
               scale_units= 'xy', 
               angles= 'xy', 
               scale= 1,
               width= 0.005,
               color= 'm',
               headwidth= 5)
    plt.plot(xq, yq, 'o', markersize= 0.5, color= 'm')

    plt.grid()
    plt.title(title, fontsize= 20)
    plt.show()
